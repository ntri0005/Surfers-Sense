# %% [markdown]
# # Team Intro:
# * Team: Aqua Wizards
# * Contributors: Akshay Ijantkar, Nishant Tripathi, Jadzia Xie
# * Project: Surfers Bible

# %%
# !pip install --user pygeocoder
# !pip install --user geopandas
# !pip install --user geopy
# !pip install  googlemaps
# !pip install weather-au
# !pip install pyowm

# %% [markdown]
# # Import Libraries:

# %%
import pandas as pd
import numpy as np
import random
import matplotlib as plt
from matplotlib import pyplot
import seaborn as sns; sns.set()
from scipy.stats import norm 
import matplotlib.pyplot as plt
# For Linear regression
from sklearn.linear_model import LinearRegression
# For split given dataset into train and test set.
from sklearn.model_selection import train_test_split
# To verify models using this metrics 
from sklearn.metrics import mean_squared_error, r2_score

import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# v
from matplotlib import rcParams
rcParams['figure.figsize'] = 50,50
import pandas_profiling
pd.set_option('display.max_rows', 1500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
from pandas import ExcelWriter
from pandas import ExcelFile

from pygeocoder import Geocoder

import sys
from weather_au import api
from weather_au import summary
from weather import place, observations, uv_index
import time

import json
import requests
from datetime import datetime, timedelta
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split

from sklearn.metrics import r2_score
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_validate

import catboost as ctb
from catboost import CatBoostRegressor, FeaturesData, Pool
from scipy.stats import uniform as sp_randFloat
from scipy.stats import randint as sp_randInt
from scipy.stats import uniform
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics.pairwise import cosine_similarity
from  sklearn.metrics.pairwise import euclidean_distances
from sklearn.metrics.pairwise import manhattan_distances
from sklearn.metrics.pairwise import pairwise_distances
import re

# %matplotlib inline

# %% [markdown]
# # Load CSV clean addresses with Coordinates CSV as Dataframe:

# %%
dataset_path = r"D:\Monash_University_Stuff\Final_Semester\IE\Surfers_Bible_Code_Commit\Datasets\\"
join_shark_weather_df = pd.read_csv(dataset_path + "for_ml_join_shark_weather_df.csv")
# raw_shark_df = pd.read_excel(dataset_path + "shark_file_geolocation_checkpoint.xlsx")
print("join_shark_weather_df.shape = ", join_shark_weather_df.shape)

join_shark_weather_df.tail(5)
# Out:
# join_shark_weather_df.shape =  (707, 80)
# ...

# %% [markdown]
# ## Numeric and Categorical Features:

# %%
numeric_features_lst = ['temperature_max',
 'temperature_min',
 'temperature_mean',
 'temperature_median',
 'temperature_std',
 'temperature_var',
 'temperature_sem',
 'apparentTemperature_max',
 'apparentTemperature_min',
 'apparentTemperature_mean',
 'apparentTemperature_median',
 'apparentTemperature_std',
 'apparentTemperature_var',
 'apparentTemperature_sem',
 'dewPoint_max',
 'dewPoint_min',
 'dewPoint_mean',
 'dewPoint_median',
 'dewPoint_std',
 'dewPoint_var',
 'dewPoint_sem',
 'humidity_max',
 'humidity_min',
 'humidity_mean',
 'humidity_median',
 'humidity_std',
 'humidity_var',
 'humidity_sem',
 'windSpeed_max',
 'windSpeed_min',
 'windSpeed_mean',
 'windSpeed_median',
 'windSpeed_std',
 'windSpeed_var',
 'windSpeed_sem',
 'windBearing_max',
 'windBearing_min',
 'windBearing_mean',
 'windBearing_median',
 'windBearing_std',
 'windBearing_var',
 'windBearing_sem',
 'uvIndex_max',
 'uvIndex_min',
 'uvIndex_mean',
 'uvIndex_median',
 'uvIndex_std',
 'uvIndex_var',
 'uvIndex_sem',
 'cloudCover_max',
 'cloudCover_min',
 'cloudCover_mean',
 'cloudCover_median',
 'cloudCover_std',
 'cloudCover_var',
 'cloudCover_sem',
 'lat','lng'
]
cat_features_lst = [
 'month',
 'month_day',
 'season']

# %% [markdown]
# # Using Cosine Similarity:

# %%
cosine_similarity(X = join_shark_weather_df.loc[1,numeric_features_lst].values.reshape(1, -1), 
                  Y = join_shark_weather_df.loc[2,numeric_features_lst].values.reshape(1, -1), 
                  dense_output=True).flatten()[0]
# Out:
# 0.6486534767985597

# %%
for index, row in join_shark_weather_df.iterrows():
    if index < 706:
        cosine_similarity_score = cosine_similarity(X = join_shark_weather_df.loc[1,numeric_features_lst].values.reshape(1, -1), 
                                                  Y = join_shark_weather_df.loc[index,numeric_features_lst].values.reshape(1, -1), 
                                                  dense_output=True).flatten()[0]
        print("index = ", index, "cosine_similarity_score = ", cosine_similarity_score, )
# Out:
# index =  0 cosine_similarity_score =  0.9270519811314347
# index =  1 cosine_similarity_score =  0.9999999999999999
# index =  2 cosine_similarity_score =  0.6486534767985597
# index =  3 cosine_similarity_score =  0.4471006947988652
# index =  4 cosine_similarity_score =  0.9618067610460496
# index =  5 cosine_similarity_score =  0.807752015324365
# index =  6 cosine_similarity_score =  0.24794516701661556
# index =  7 cosine_similarity_score =  0.9868146433656003
# index =  8 cosine_similarity_score =  0.9662452415441232
# index =  9 cosine_similarity_score =  0.2508042072149027
# index =  10 cosine_similarity_score =  0.8000368843592491
# index =  11 cosine_similarity_score =  0.3270223112744067
# index =  12 cosine_similarity_score =  0.48419892832539246
# index =  13 cosine_similarity_score =  0.9556387446821053
# index =  14 cosine_similarity_score =  0.27923566373349207
# index =  15 cosine_similarity_score =  0.5999996442791073
# ...

# %% [markdown]
# ### IF cosine similarity of new data is more than 0.5 for 70% percent of population distribution then chances of shark attack

# %% [markdown]
# ## Using Euclidean_Distances:

# %%
euclidean_distances(X = join_shark_weather_df.loc[1,numeric_features_lst].values.reshape(1, -1), 
                  Y = join_shark_weather_df.loc[2,numeric_features_lst].values.reshape(1, -1), 
                  ).flatten()[0]
# Out:
# 485.19858657357827

# %%
for index, row in join_shark_weather_df.iterrows():
    if index < 706:
        euclidean_distances_score = euclidean_distances(X = join_shark_weather_df.loc[1,numeric_features_lst].values.reshape(1, -1), 
                                                  Y = join_shark_weather_df.loc[index,numeric_features_lst].values.reshape(1, -1), 
                                                  ).flatten()[0]
        print("index = ", index, "euclidean_distances_score = ", euclidean_distances_score, )
# Out:
# index =  0 euclidean_distances_score =  192.92455653774036
# index =  1 euclidean_distances_score =  0.0
# index =  2 euclidean_distances_score =  485.19858657357827
# index =  3 euclidean_distances_score =  1703.248326763227
# index =  4 euclidean_distances_score =  105.73093160029174
# index =  5 euclidean_distances_score =  477.67024136664594
# index =  6 euclidean_distances_score =  23706.975198371932
# index =  7 euclidean_distances_score =  66.33770863568306
# index =  8 euclidean_distances_score =  95.06949619265126
# index =  9 euclidean_distances_score =  25087.2405757755
# index =  10 euclidean_distances_score =  398.0605041694461
# index =  11 euclidean_distances_score =  5171.420342880312
# index =  12 euclidean_distances_score =  1146.435854664574
# index =  13 euclidean_distances_score =  112.63003579531808
# index =  14 euclidean_distances_score =  9126.834599133757
# index =  15 euclidean_distances_score =  957.3274460492818
# ...

# %% [markdown]
# ## Using Manhattan distance:

# %%
manhattan_distances(X = join_shark_weather_df.loc[1,numeric_features_lst].values.reshape(1, -1), 
                  Y = join_shark_weather_df.loc[2,numeric_features_lst].values.reshape(1, -1), 
                  ).flatten()[0]
# Out:
# 949.0490485440126

# %%
for index, row in join_shark_weather_df.iterrows():
    if index < 706:
        manhattan_distances_score = manhattan_distances(X = join_shark_weather_df.loc[1,numeric_features_lst].values.reshape(1, -1), 
                                                  Y = join_shark_weather_df.loc[index,numeric_features_lst].values.reshape(1, -1), 
                                                  ).flatten()[0]
        print("index = ", index, "manhattan_distances_score = ", manhattan_distances_score, )
# Out:
# index =  0 manhattan_distances_score =  523.7985357484238
# index =  1 manhattan_distances_score =  0.0
# index =  2 manhattan_distances_score =  949.0490485440126
# index =  3 manhattan_distances_score =  2362.2394004190032
# index =  4 manhattan_distances_score =  269.18507965152276
# index =  5 manhattan_distances_score =  1171.3329014498845
# index =  6 manhattan_distances_score =  24393.64779825734
# index =  7 manhattan_distances_score =  247.9310716994547
# index =  8 manhattan_distances_score =  258.1755723968796
# index =  9 manhattan_distances_score =  26116.72684549965
# index =  10 manhattan_distances_score =  961.6328569001535
# index =  11 manhattan_distances_score =  6086.0444605953435
# index =  12 manhattan_distances_score =  1936.4956191293234
# index =  13 manhattan_distances_score =  348.32463434207085
# index =  14 manhattan_distances_score =  10126.54876794142
# index =  15 manhattan_distances_score =  2054.7936614323044
# ...

# %% [markdown]
# ## Using Minkowski distance

# %%
pairwise_distances(X = join_shark_weather_df.loc[1,numeric_features_lst].values.reshape(1, -1), 
                  Y = join_shark_weather_df.loc[2,numeric_features_lst].values.reshape(1, -1), 
                   metric='minkowski'
                  ).flatten()[0]
# Out:
# 485.1985865735782

# %%
for index, row in join_shark_weather_df.iterrows():
    if index < 706:
        minkowski_distances_score = pairwise_distances(
                                        X = join_shark_weather_df.loc[1,numeric_features_lst].values.reshape(1, -1), 
                                        Y = join_shark_weather_df.loc[index,numeric_features_lst].values.reshape(1, -1), 
                                        metric='minkowski',                
                                                  ).flatten()[0]
        print("index = ", index, "minkowski_distances_score = ", minkowski_distances_score, )
# Out:
# index =  0 minkowski_distances_score =  192.9245565377407
# index =  1 minkowski_distances_score =  0.0
# index =  2 minkowski_distances_score =  485.1985865735782
# index =  3 minkowski_distances_score =  1703.248326763227
# index =  4 minkowski_distances_score =  105.73093160029171
# index =  5 minkowski_distances_score =  477.67024136664594
# index =  6 minkowski_distances_score =  23706.975198371932
# index =  7 minkowski_distances_score =  66.33770863568346
# index =  8 minkowski_distances_score =  95.06949619265133
# index =  9 minkowski_distances_score =  25087.2405757755
# index =  10 minkowski_distances_score =  398.0605041694461
# index =  11 minkowski_distances_score =  5171.420342880311
# index =  12 minkowski_distances_score =  1146.435854664574
# index =  13 minkowski_distances_score =  112.63003579531818
# index =  14 minkowski_distances_score =  9126.834599133756
# index =  15 minkowski_distances_score =  957.3274460492819
# ...

# %% [markdown]
# ## Using Jaccard  distance:

# %%
pairwise_distances(X = join_shark_weather_df.loc[1,numeric_features_lst].values.reshape(1, -1), 
                  Y = join_shark_weather_df.loc[2,numeric_features_lst].values.reshape(1, -1), 
                   metric='jaccard'
                  ).flatten()[0]
# Out:
# C:\Users\aksha\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1575: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# 0.03571428571428571

# %%
for index, row in join_shark_weather_df.iterrows():
    if index < 706:
        jaccard_distances_score = pairwise_distances(
                                        X = join_shark_weather_df.loc[1,numeric_features_lst].values.reshape(1, -1), 
                                        Y = join_shark_weather_df.loc[index,numeric_features_lst].values.reshape(1, -1), 
                                        metric='jaccard',                
                                                  ).flatten()[0]
        print("index = ", index, "jaccard_distances_score = ", jaccard_distances_score, )
# Out:
# C:\Users\aksha\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1575: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\aksha\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1575: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\aksha\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1575: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\aksha\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1575: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\aksha\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1575: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# ...

# %% [markdown]
# # Mahalanobis Distance:
# * Mahalonobis distance is the distance between a point and a distribution. And not between two distinct points. It is effectively a multivariate equivalent of the Euclidean distance.
# * https://www.machinelearningplus.com/statistics/mahalanobis-distance/

# %%
import scipy as sp
def mahalanobis(x=None, data=None, cov=None):
    """Compute the Mahalanobis Distance between each row of x and the data  
    x    : vector or matrix of data with, say, p columns.
    data : ndarray of the distribution from which Mahalanobis distance of each observation of x is to be computed.
    cov  : covariance matrix (p x p) of the distribution. If None, will be computed from data.
    """
    x_minus_mu = x - np.mean(data)
    if not cov:
        cov = np.cov(data.values.T)
    inv_covmat = sp.linalg.inv(cov)
    left_term = np.dot(x_minus_mu, inv_covmat)
    mahal = np.dot(left_term, x_minus_mu.T)
    return mahal.diagonal()

# %%
mahalanobis(x = join_shark_weather_df.loc[9:9,numeric_features_lst], 
                  data = join_shark_weather_df.loc[10:,numeric_features_lst] ).flatten()
# Out:
# array([85.48631319])

# %%
for index, row in join_shark_weather_df.iterrows():
    mahalanobis_dist = mahalanobis(x = join_shark_weather_df.loc[index:index,numeric_features_lst], 
                  data = join_shark_weather_df.loc[:,numeric_features_lst].drop(join_shark_weather_df.loc[:,numeric_features_lst].index[index]) ).flatten()
    print("index = ", index, "mahalanobis_dist = ", mahalanobis_dist, )
# Out:
# index =  0 mahalanobis_dist =  [32.04369974]
# index =  1 mahalanobis_dist =  [35.30963652]
# index =  2 mahalanobis_dist =  [61.15106032]
# index =  3 mahalanobis_dist =  [54.65707975]
# index =  4 mahalanobis_dist =  [29.19771473]
# index =  5 mahalanobis_dist =  [53.00227836]
# index =  6 mahalanobis_dist =  [46.00479219]
# index =  7 mahalanobis_dist =  [29.87493948]
# index =  8 mahalanobis_dist =  [23.6907183]
# index =  9 mahalanobis_dist =  [83.97545633]
# index =  10 mahalanobis_dist =  [13.59112372]
# index =  11 mahalanobis_dist =  [79.38236711]
# index =  12 mahalanobis_dist =  [69.88170735]
# index =  13 mahalanobis_dist =  [42.92328794]
# index =  14 mahalanobis_dist =  [30.12007658]
# index =  15 mahalanobis_dist =  [47.4489042]
# index =  16 mahalanobis_dist =  [35.20899422]
# index =  17 mahalanobis_dist =  [21.80679832]
# index =  18 mahalanobis_dist =  [36.77945894]
# index =  19 mahalanobis_dist =  [59.23348687]
# index =  20 mahalanobis_dist =  [26.85844732]
# ...
