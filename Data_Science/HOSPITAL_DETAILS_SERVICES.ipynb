# %% [markdown]
# # Import Libraries:

# %%
import pandas as pd
import numpy as np
import random
import matplotlib as plt
from matplotlib import pyplot
# import seaborn as sns; sns.set()
# from scipy.stats import norm 
import matplotlib.pyplot as plt
# For Linear regression
# from sklearn.linear_model import LinearRegression
# For split given dataset into train and test set.
# from sklearn.model_selection import train_test_split
# To verify models using this metrics 
# from sklearn.metrics import mean_squared_error, r2_score

# import statsmodels.formula.api as smf
# from sklearn.linear_model import LinearRegression
# from sklearn import metrics
# v
from matplotlib import rcParams
rcParams['figure.figsize'] = 50,50
import pandas_profiling
pd.set_option('display.max_rows', 1500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
from pandas import ExcelWriter
from pandas import ExcelFile

from pygeocoder import Geocoder

import sys
# from weather_au import api
# from weather_au import summary
# from weather import place, observations, uv_index
import time

import json
import requests
from datetime import datetime, timedelta
# from catboost import CatBoostClassifier
# from sklearn.model_selection import train_test_split

# from sklearn.metrics import r2_score
# from keras.models import Sequential
# from keras.layers import Dense
# from keras.wrappers.scikit_learn import KerasRegressor
# from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import KFold
# from sklearn.model_selection import cross_validate

# import catboost as ctb
# from catboost import CatBoostRegressor, FeaturesData, Pool
# from scipy.stats import uniform as sp_randFloat
# from scipy.stats import randint as sp_randInt
# from scipy.stats import uniform
# from sklearn.model_selection import RandomizedSearchCV
# from sklearn.metrics.pairwise import cosine_similarity
# from  sklearn.metrics.pairwise import euclidean_distances
# from sklearn.metrics.pairwise import manhattan_distances
# from sklearn.metrics.pairwise import pairwise_distances
import re
# import pprint
from datetime import date
import datetime
# import sqlite3
# from sqlite3 import Error
from datetime import datetime
from dateutil import tz
import datetime

# %matplotlib inline
# Out:
# C:\Users\aksha\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
url_str = "https://maps.googleapis.com/maps/api/place/details/json?place_id="
url_str += "ChIJu27KfLu8EmsR8CSVN3mcs_4"
url_str += "&fields="
url_str += "address_component,adr_address,business_status,formatted_address,geometry,icon,name,permanently_closed,photo,place_id,plus_code,type,url,utc_offset,vicinity,formatted_phone_number,international_phone_number,opening_hours,website,price_level,rating,review,user_ratings_total"
url_str += "&key=AIzaSyD6YiLVh4V_51fDGpmSAjNSkjlD6myuhsY"

response_dict = json.loads(requests.get(url_str).text)
response_dict
# Out:
# {'html_attributions': [],
#  'result': {'address_components': [{'long_name': 'Hargrave Road',
#     'short_name': 'Hargrave Rd',
#     'types': ['route']},
#    {'long_name': 'Auburn',
#     'short_name': 'Auburn',
#     'types': ['locality', 'political']},
#    {'long_name': 'Cumberland Council',
#     'short_name': 'Cumberland Council',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'New South Wales',
#     'short_name': 'NSW',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Australia',
#     'short_name': 'AU',
#     'types': ['country', 'political']},
#    {'long_name': '2144', 'short_name': '2144', 'types': ['postal_code']}],
#   'adr_address': '<span class="street-address">Hargrave Rd</span>, <span class="locality">Auburn</span> <span class="region">NSW</span> <span class="postal-code">2144</span>, <span class="country-name">Australia</span>',
#   'business_status': 'OPERATIONAL',
# ...

# %%
response_dict.keys()
# Out:
# dict_keys(['html_attributions', 'result', 'status'])

# %%
response_dict["result"]
# Out:
# {'address_components': [{'long_name': 'Hargrave Road',
#    'short_name': 'Hargrave Rd',
#    'types': ['route']},
#   {'long_name': 'Auburn',
#    'short_name': 'Auburn',
#    'types': ['locality', 'political']},
#   {'long_name': 'Cumberland Council',
#    'short_name': 'Cumberland Council',
#    'types': ['administrative_area_level_2', 'political']},
#   {'long_name': 'New South Wales',
#    'short_name': 'NSW',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': 'Australia',
#    'short_name': 'AU',
#    'types': ['country', 'political']},
#   {'long_name': '2144', 'short_name': '2144', 'types': ['postal_code']}],
#  'adr_address': '<span class="street-address">Hargrave Rd</span>, <span class="locality">Auburn</span> <span class="region">NSW</span> <span class="postal-code">2144</span>, <span class="country-name">Australia</span>',
#  'business_status': 'OPERATIONAL',
#  'formatted_address': 'Hargrave Rd, Auburn NSW 2144, Australia',
# ...

# %%
response_dict["result"].keys()
# Out:
# dict_keys(['address_components', 'adr_address', 'business_status', 'formatted_address', 'formatted_phone_number', 'geometry', 'icon', 'international_phone_number', 'name', 'opening_hours', 'photos', 'place_id', 'plus_code', 'rating', 'reviews', 'types', 'url', 'user_ratings_total', 'utc_offset', 'vicinity', 'website'])

# %%
response_dict["result"]['address_components']
# Out:
# [{'long_name': 'Hargrave Road',
#   'short_name': 'Hargrave Rd',
#   'types': ['route']},
#  {'long_name': 'Auburn',
#   'short_name': 'Auburn',
#   'types': ['locality', 'political']},
#  {'long_name': 'Cumberland Council',
#   'short_name': 'Cumberland Council',
#   'types': ['administrative_area_level_2', 'political']},
#  {'long_name': 'New South Wales',
#   'short_name': 'NSW',
#   'types': ['administrative_area_level_1', 'political']},
#  {'long_name': 'Australia',
#   'short_name': 'AU',
#   'types': ['country', 'political']},
#  {'long_name': '2144', 'short_name': '2144', 'types': ['postal_code']}]

# %%
response_dict["result"]['adr_address']
# Out:
# '<span class="street-address">Hargrave Rd</span>, <span class="locality">Auburn</span> <span class="region">NSW</span> <span class="postal-code">2144</span>, <span class="country-name">Australia</span>'

# %%
response_dict["result"]['business_status']
# Out:
# 'OPERATIONAL'

# %%
response_dict["result"]['formatted_phone_number']
# Out:
# '(02) 8759 3000'

# %%
response_dict["result"]['geometry']
# Out:
# {'location': {'lat': -33.8605222, 'lng': 151.0325624},
#  'viewport': {'northeast': {'lat': -33.8591644697085,
#    'lng': 151.0338491302915},
#   'southwest': {'lat': -33.8618624302915, 'lng': 151.0311511697085}}}

# %%
response_dict["result"]['icon']
# Out:
# 'https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png'

# %%
response_dict["result"]['international_phone_number']
# Out:
# '+61 2 8759 3000'

# %%
response_dict["result"]['name']
# Out:
# 'Auburn Hospital'

# %%
response_dict["result"]['opening_hours']
# Out:
# {'open_now': True,
#  'periods': [{'open': {'day': 0, 'time': '0000'}}],
#  'weekday_text': ['Monday: Open 24 hours',
#   'Tuesday: Open 24 hours',
#   'Wednesday: Open 24 hours',
#   'Thursday: Open 24 hours',
#   'Friday: Open 24 hours',
#   'Saturday: Open 24 hours',
#   'Sunday: Open 24 hours']}

# %%
response_dict["result"]['opening_hours']['periods']
# Out:
# [{'open': {'day': 0, 'time': '0000'}}]

# %%
response_dict["result"]['opening_hours']['weekday_text']
# Out:
# ['Monday: Open 24 hours',
#  'Tuesday: Open 24 hours',
#  'Wednesday: Open 24 hours',
#  'Thursday: Open 24 hours',
#  'Friday: Open 24 hours',
#  'Saturday: Open 24 hours',
#  'Sunday: Open 24 hours']

# %%
response_dict["result"]['photos']
# Out:
# [{'height': 1080,
#   'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106508113530578139772">kamran haider</a>'],
#   'photo_reference': 'CmRaAAAAe9StiQobfcbY0fjr8qfcIS46_y08TxgzmawAP1MxtwcLgsMIX5dP4KJiScPSr6e64r-_n9y6T5cGLpRo4Qhe2dc42jbPKOBa1-iSjq7RxL054KaOdPxymBvNBi8z9rGIEhD7weccjgM76Reryr_xazKVGhSWEIgq4ieoa4BRZH7vYa0I26Uzmw',
#   'width': 1920},
#  {'height': 1080,
#   'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108683873468861119509">Hal Cecen</a>'],
#   'photo_reference': 'CmRaAAAAVKZr_-smbfKhxmA2QfPsjQyCcAERNgBdIcLeKQrasl6KtGV2HsO10yl6k--BKorXwtmRDuYJJYXhLd_sxdFmeAeef8yxwvMsnXzDhBOgswmEVCspalA9WfXRCSH5xKdHEhCCydvvI8rqDsX1xGUHjSJZGhR2uqHiEdt2QX7SVJm6Ogx3SluxDA',
#   'width': 1920},
#  {'height': 4128,
#   'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106825673801854950520">Jaala May</a>'],
# ...

# %%
response_dict["result"]["plus_code"]
# Out:
# {'compound_code': '42QM+Q2 Auburn, New South Wales, Australia',
#  'global_code': '4RRH42QM+Q2'}

# %%
response_dict["result"]["rating"]
# Out:
# 2.5

# %%
response_dict["result"]["types"]
# Out:
# ['hospital', 'health', 'point_of_interest', 'establishment']

# %%
response_dict["result"]["url"]
# Out:
# 'https://maps.google.com/?cid=18353184950902400240'

# %%
response_dict["result"]["user_ratings_total"]
# Out:
# 206

# %%
response_dict["result"]["utc_offset"]
# Out:
# 600

# %%
response_dict["result"]["vicinity"]
# Out:
# 'Hargrave Road, Auburn'

# %%
response_dict["result"]["website"]
# Out:
# 'http://www.wslhd.health.nsw.gov.au/Auburn-Hospital'

# %%
req_cols_dict = {}
req_cols_dict["business_status"] = response_dict["result"]['business_status']
req_cols_dict["icon_url"] = response_dict["result"]['icon']
req_cols_dict["international_phone_number"] = response_dict["result"]['international_phone_number']
req_cols_dict["opening_hours_weekday_text"] = response_dict["result"]['opening_hours']['weekday_text']
req_cols_dict["rating"] = response_dict["result"]["rating"]
req_cols_dict["geo_url"] = response_dict["result"]["url"]
req_cols_dict["user_ratings_total"] = response_dict["result"]["user_ratings_total"]
req_cols_dict["utc_offset"] = response_dict["result"]["utc_offset"]
req_cols_dict["vicinity"] = response_dict["result"]["vicinity"]
req_cols_dict["website_url"] = response_dict["result"]["website"]
req_cols_dict
# Out:
# {'business_status': 'OPERATIONAL',
#  'icon_url': 'https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png',
#  'international_phone_number': '+61 2 8759 3000',
#  'opening_hours_weekday_text': ['Monday: Open 24 hours',
#   'Tuesday: Open 24 hours',
#   'Wednesday: Open 24 hours',
#   'Thursday: Open 24 hours',
#   'Friday: Open 24 hours',
#   'Saturday: Open 24 hours',
#   'Sunday: Open 24 hours'],
#  'rating': 2.5,
#  'geo_url': 'https://maps.google.com/?cid=18353184950902400240',
#  'user_ratings_total': 206,
#  'utc_offset': 600,
#  'vicinity': 'Hargrave Road, Auburn',
#  'website_url': 'http://www.wslhd.health.nsw.gov.au/Auburn-Hospital'}

# %%
req_cols_dict.keys()
# Out:
# dict_keys(['business_status', 'icon_url', 'international_phone_number', 'opening_hours_weekday_text', 'rating', 'geo_url', 'user_ratings_total', 'utc_offset', 'vicinity', 'website_url'])

# %%
dataset_path = r"D:\Monash_University_Stuff\Final_Semester\IE\Surfers_Bible_Code_Commit\Datasets\\"
hospital_df = pd.read_csv(dataset_path + "req_hos_wt_time_df.csv")
# raw_shark_df = pd.read_excel(dataset_path + "req_hos_wt_time_df.xlsx")
print("hospital_df.shape = ", hospital_df.shape)

hospital_df.head(5)
# Out:
# hospital_df.shape =  (370, 18)
#                                      hospital_name                                   hospital_address            state  peer_group hospital_type interval time_period  resuscitation_cohort_percent_patient_seen_on_time  emergency_cohort_percent_patient_seen_on_time  urgent_cohort_percent_patient_seen_on_time  semi_urgent_cohort_percent_patient_seen_on_time  non_urgent_cohort_percent_patient_seen_on_time  hospital_latitude  hospital_longitude hospital_location_type   hospital_postal_code                     hospital_formatted_address            hospital_place_id
# ...

# %%
hospital_df.state.unique()
# Out:
# array(['New South Wales', 'Victoria', 'Queensland', 'South Australia',
#        'Western Australia', 'Tasmania', 'Northern Territory',
#        ' Australian Capital Territory'], dtype=object)

# %%
hospital_df.loc[hospital_df["state"] == "Victoria", :].shape
# Out:
# (65, 18)

# %%
hospital_df = hospital_df.loc[hospital_df["state"] == "Victoria", :].copy()
hospital_df.reset_index(inplace = True, drop = True)
hospital_df.head()
# Out:
#                                       hospital_name                                   hospital_address     state  peer_group           hospital_type interval time_period  resuscitation_cohort_percent_patient_seen_on_time  emergency_cohort_percent_patient_seen_on_time  urgent_cohort_percent_patient_seen_on_time  semi_urgent_cohort_percent_patient_seen_on_time  non_urgent_cohort_percent_patient_seen_on_time  hospital_latitude  hospital_longitude hospital_location_type hospital_postal_code                         hospital_formatted_address            hospital_place_id
# ...

# %%
req_cols_lst =["business_status", "icon_url", "international_phone_number", "opening_hours_weekday_text", "rating", "geo_url", 
 "user_ratings_total", "utc_offset", "vicinity", "website_url"]
for col in req_cols_lst:
    hospital_df[col] = ""
hospital_df
# Out:
#                                         hospital_name                                   hospital_address     state  peer_group           hospital_type interval time_period  resuscitation_cohort_percent_patient_seen_on_time  emergency_cohort_percent_patient_seen_on_time  urgent_cohort_percent_patient_seen_on_time  semi_urgent_cohort_percent_patient_seen_on_time  non_urgent_cohort_percent_patient_seen_on_time  hospital_latitude  hospital_longitude hospital_location_type     hospital_postal_code                         hospital_formatted_address            hospital_place_id business_status icon_url international_phone_number opening_hours_weekday_text rating geo_url user_ratings_total utc_offset vicinity website_url
# ...

# %%
for index, row in hospital_df.iterrows():
    url_str = "https://maps.googleapis.com/maps/api/place/details/json?place_id="
    url_str += row["hospital_place_id"].strip()
    url_str += "&fields="
    url_str += "address_component,adr_address,business_status,formatted_address,geometry,icon,name,permanently_closed,photo,place_id,plus_code,type,url,utc_offset,vicinity,formatted_phone_number,international_phone_number,opening_hours,website,price_level,rating,review,user_ratings_total"
    url_str += "&key=AIzaSyD6YiLVh4V_51fDGpmSAjNSkjlD6myuhsY"
    try:
        response_dict = json.loads(requests.get(url_str).text)
        print("index = ",index)
        print("hospital_name = ",row["hospital_name"])
        hospital_df.loc[index, "business_status"] = response_dict["result"]['business_status']
        hospital_df.loc[index, "icon_url"] = response_dict["result"]['icon']
        hospital_df.loc[index, "international_phone_number"] = response_dict["result"]['international_phone_number']
        hospital_df.loc[index, "opening_hours_weekday_text"] = str(response_dict["result"]['opening_hours']['weekday_text'])
        hospital_df.loc[index, "rating"] = response_dict["result"]["rating"]
        hospital_df.loc[index, "geo_url"] = response_dict["result"]["url"]
        hospital_df.loc[index, "user_ratings_total"] = response_dict["result"]["user_ratings_total"]
        hospital_df.loc[index, "utc_offset"] = response_dict["result"]["utc_offset"]
        hospital_df.loc[index, "vicinity"] = response_dict["result"]["vicinity"]
        hospital_df.loc[index, "website_url"] = response_dict["result"]["website"]
    except:
        
        print("+++++++++++++++++++++++++++++++++++++++++++++++++++++")
        print("index = ",index)
        print("hospital_name = ",row["hospital_name"])
        print("+++++++++++++++++++++++++++++++++++++++++++++++++++++")
    
    
#     req_cols_dict    
#     response_dict
# Out:
# index =  0
# hospital_name =  Albury Wodonga Health Hospital,
# index =  1
# hospital_name =  Albury Wodonga Health [Wodonga Campus] Hospital,
# index =  2
# hospital_name =  Alfred Health (Vic) Hospital,
# index =  3
# hospital_name =  Angliss Hospital Hospital,
# index =  4
# hospital_name =  Austin Health (Vic) Hospital,
# +++++++++++++++++++++++++++++++++++++++++++++++++++++
# index =  4
# hospital_name =  Austin Health (Vic) Hospital,
# +++++++++++++++++++++++++++++++++++++++++++++++++++++
# index =  5
# hospital_name =  Austin Hospital [Heidelberg] Hospital,
# index =  6
# hospital_name =  Bairnsdale Regional Health Service Hospital,
# index =  7
# hospital_name =  Ballarat Health Services Hospital,
# index =  8
# hospital_name =  Ballarat Health Services [Base Campus] Hospital,
# index =  9
# hospital_name =  Barwon Health Hospital,
# index =  10
# hospital_name =  Bass Coast Regional Health Hospital,
# index =  11
# hospital_name =  Bendigo Health Care Group Hospital,
# ...

# %%
response_dict["result"]['opening_hours']['weekday_text']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-bc4ef95e0e62> in <module>
# ----> 1 response_dict["result"]['opening_hours']['weekday_text']
#
# KeyError: 'opening_hours'

# %%
hospital_df.to_csv(r"D:\Monash_University_Stuff\Final_Semester\IE\Surfers_Bible_Code_Commit\Datasets\update_hospital_df.csv", index = False)

# %%
dataset_path = r"D:\Monash_University_Stuff\Final_Semester\IE\Surfers_Bible_Code_Commit\Datasets\\"
hospital_df = pd.read_csv(dataset_path + "update_hospital_df.csv")
# raw_shark_df = pd.read_excel(dataset_path + "req_hos_wt_time_df.xlsx")
print("hospital_df.shape = ", hospital_df.shape)

hospital_df.head(5)
# Out:
# hospital_df.shape =  (65, 28)
#                             hospital_name                                   hospital_address     state  peer_group           hospital_type interval time_period  resuscitation_cohort_percent_patient_seen_on_time  emergency_cohort_percent_patient_seen_on_time  urgent_cohort_percent_patient_seen_on_time  semi_urgent_cohort_percent_patient_seen_on_time  non_urgent_cohort_percent_patient_seen_on_time  hospital_latitude  hospital_longitude hospital_location_type hospital_postal_code                         hospital_formatted_address            hospital_place_id business_status                                           icon_url international_phone_number                         opening_hours_weekday_text  rating                                            geo_url  user_ratings_total  utc_offset                                vicinity                                        website_url
# ...

# %% [markdown]
# # CREATE SEA_WATER_QUALITY_TABLE:

# %%
import psycopg2 as ps

# define credentials 
credentials = {'POSTGRES_ADDRESS' : 'test-surfers-bible-instance.cljoljhkgpfb.ap-southeast-2.rds.amazonaws.com', # change to your endpoint
               'POSTGRES_PORT' : 5432, # change to your port
               'POSTGRES_USERNAME' : 'ai_postgres', # change to your username
               'POSTGRES_PASSWORD' : 'postgres2309', # change to your password
               'POSTGRES_DBNAME' : 'test_surfers_bible_db'} # change to your db name

# create connection and cursor    
conn = ps.connect(host=credentials['POSTGRES_ADDRESS'],
                  database=credentials['POSTGRES_DBNAME'],
                  user=credentials['POSTGRES_USERNAME'],
                  password=credentials['POSTGRES_PASSWORD'],
                  port=credentials['POSTGRES_PORT'])

cur = conn.cursor()

# cur.execute("DROP TABLE SEA_WATER_QUALITY_TABLE;")

create_table_query = '''
      CREATE TABLE IF NOT EXISTS hospital_table
      (
        hospital_id SERIAL PRIMARY KEY,
        hospital_name TEXT,
        hospital_address TEXT,
        state TEXT,
        peer_group TEXT,
        hospital_type TEXT,
        interval TEXT,
        time_period TEXT,
        resuscitation_cohort_percent_patient_seen_on_time REAL,
        emergency_cohort_percent_patient_seen_on_time REAL,
        urgent_cohort_percent_patient_seen_on_time REAL,
        semi_urgent_cohort_percent_patient_seen_on_time REAL,
        non_urgent_cohort_percent_patient_seen_on_time REAL,
        hospital_latitude REAL,
        hospital_longitude REAL,
        hospital_location_type TEXT,
        hospital_postal_code TEXT,
        hospital_formatted_address TEXT,
        hospital_place_id TEXT,
        business_status TEXT,
        icon_url TEXT,
        international_phone_number TEXT,
        opening_hours_weekday_text TEXT,
        rating REAL,
        geo_url TEXT,
        user_ratings_total REAL,
        utc_offset REAL,
        vicinity TEXT,
        website_url TEXT
       ); 
       '''

cur.execute(create_table_query)
conn.commit()

cur.close()
conn.close()

# %% [markdown]
# # INSERT SEA_WATER_QUALITY_TABLE:

# %%
# %%time
# Wall time: 12min 51s
import psycopg2 as ps

# define credentials 
credentials = {'POSTGRES_ADDRESS' : 'test-surfers-bible-instance.cljoljhkgpfb.ap-southeast-2.rds.amazonaws.com', # change to your endpoint
               'POSTGRES_PORT' : 5432, # change to your port
               'POSTGRES_USERNAME' : 'ai_postgres', # change to your username
               'POSTGRES_PASSWORD' : 'postgres2309', # change to your password
               'POSTGRES_DBNAME' : 'test_surfers_bible_db'} # change to your db name

# create connection and cursor    
conn = ps.connect(host=credentials['POSTGRES_ADDRESS'],
                  database=credentials['POSTGRES_DBNAME'],
                  user=credentials['POSTGRES_USERNAME'],
                  password=credentials['POSTGRES_PASSWORD'],
                  port=credentials['POSTGRES_PORT'])

cur = conn.cursor()

fill_question_mark_str = str(tuple(["%s"  for i in hospital_df.columns.tolist()])).replace("'", "")
fill_question_mark_str

for row in hospital_df.itertuples():
    data_tuple = tuple(row[1:])

    print("data_tuple = ", data_tuple)
    print(" ")
    
    cur.execute("""
                        INSERT INTO hospital_table
                        (
        hospital_name,
        hospital_address,
        state,
        peer_group,
        hospital_type,
        interval,
        time_period,
        resuscitation_cohort_percent_patient_seen_on_time,
        emergency_cohort_percent_patient_seen_on_time,
        urgent_cohort_percent_patient_seen_on_time,
        semi_urgent_cohort_percent_patient_seen_on_time,
        non_urgent_cohort_percent_patient_seen_on_time,
        hospital_latitude,
        hospital_longitude,
        hospital_location_type,
        hospital_postal_code,
        hospital_formatted_address,
        hospital_place_id,
        business_status,
        icon_url,
        international_phone_number,
        opening_hours_weekday_text,
        rating,
        geo_url,
        user_ratings_total,
        utc_offset,
        vicinity,
        website_url
                         ) VALUES  
                         """ + fill_question_mark_str + " ;"
                , data_tuple)    

conn.commit()
cur.close()
conn.close()
# Out:
# data_tuple =  ('Albury Wodonga Health', 'Albury Wodonga Health Hospital, Victoria, Australia', 'Victoria', 'Not peered', 'Local hospital network', 'FY', '2018–19', 100.0, 81, 66, 73, 94, -36.0785951, 146.9377197, 'ROOFTOP', 'New South Wales', '201 Borella Rd, Albury NSW 2640, Australia', 'ChIJL6QGAMzhI2sRENL9c7UJBg8', 'OPERATIONAL', 'https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png', '+61 2 6058 4444', "['Monday: Open 24 hours', 'Tuesday: Open 24 hours', 'Wednesday: Open 24 hours', 'Thursday: Open 24 hours', 'Friday: Open 24 hours', 'Saturday: Open 24 hours', 'Sunday: Open 24 hours']", 2.9, 'https://maps.google.com/?cid=1082563435368927760', 44.0, 600.0, '201 Borella Road, Albury', 'http://www.awh.org.au/')
#
# ...

# %%
dataset_path = r"D:\Monash_University_Stuff\Final_Semester\IE\Surfers_Bible_Code_Commit\Datasets\\"
hospital_services_df = pd.read_csv(dataset_path + "hospital_services.csv")
# raw_shark_df = pd.read_excel(dataset_path + "req_hos_wt_time_df.xlsx")
print("hospital_services_df.shape = ", hospital_services_df.shape)

hospital_services_df.head(5)
# Out:
# hospital_services_df.shape =  (2798, 3)
#                                 Hospital State             Services
# 0  Albury Wodonga Health [Albury Campus]   NSW   Coronary care unit
# 1  Albury Wodonga Health [Albury Campus]   NSW  Intensive care unit
# 2  Albury Wodonga Health [Albury Campus]   NSW        Oncology unit
# 3  Albury Wodonga Health [Albury Campus]   NSW   Paediatric service
# 4  Albury Wodonga Health [Albury Campus]   NSW     Psychiatric unit

# %% [markdown]
# # Matching hospital names:

# %%
hospital_services_lst = hospital_services_df.loc[hospital_services_df.State == "Vic", :].Hospital.unique().tolist()

# %%
hospital_lst = hospital_df.hospital_name.unique().tolist()

# %%
len(hospital_lst)
# Out:
# 65

# %%
len(hospital_services_lst)
# Out:
# 146

# %%
len(set(hospital_services_lst).intersection(set(hospital_lst)))
# Out:
# 37

# %%
hospital_services_df.Services.unique().tolist()
# Out:
# ['Coronary care unit',
#  'Intensive care unit',
#  'Oncology unit',
#  'Paediatric service',
#  'Psychiatric unit',
#  'Domiciliary care service',
#  'Geriatric assessment unit',
#  'Hospice care unit',
#  'Maintenance renal dialysis unit',
#  'Obstetric services',
#  'Rehabilitation unit',
#  'Alcohol and drug unit',
#  'Nursing home care unit',
#  'Diabetes unit',
#  'Epilepsy centre',
#  'Infectious diseases unit',
#  'Acute renal dialysis unit',
#  'Cardiac surgery unit',
#  'Bone marrow transplantation unit',
#  'Major plastic or reconstructive surgery unit',
#  'Clinical genetics unit',
#  'AIDS unit',
#  'Burns unit',
#  'Neurosurgical unit',
#  'Neonatal intensive care unit',
#  'Sleep centre',
#  'Renal transplantation unit',
#  'Acute spinal cord injury unit',
#  'In-vitro fertilisation unit',
#  'Liver transplantation unit',
#  'Heart transplantation unit',
#  'Pancreas transplantation unit']

# %%
services_df = pd.DataFrame(hospital_services_df.Services.unique().tolist(), columns =['services']) 
services_df
# Out:
#                                         services
# 0                             Coronary care unit
# 1                            Intensive care unit
# 2                                  Oncology unit
# 3                             Paediatric service
# 4                               Psychiatric unit
# 5                       Domiciliary care service
# 6                      Geriatric assessment unit
# 7                              Hospice care unit
# 8                Maintenance renal dialysis unit
# 9                             Obstetric services
# 10                           Rehabilitation unit
# 11                         Alcohol and drug unit
# 12                        Nursing home care unit
# 13                                 Diabetes unit
# 14                               Epilepsy centre
# 15                      Infectious diseases unit
# 16                     Acute renal dialysis unit
# 17                          Cardiac surgery unit
# ...

# %% [markdown]
# # CREATE SEA_WATER_QUALITY_TABLE:

# %%
import psycopg2 as ps

# define credentials 
credentials = {'POSTGRES_ADDRESS' : 'test-surfers-bible-instance.cljoljhkgpfb.ap-southeast-2.rds.amazonaws.com', # change to your endpoint
               'POSTGRES_PORT' : 5432, # change to your port
               'POSTGRES_USERNAME' : 'ai_postgres', # change to your username
               'POSTGRES_PASSWORD' : 'postgres2309', # change to your password
               'POSTGRES_DBNAME' : 'test_surfers_bible_db'} # change to your db name

# create connection and cursor    
conn = ps.connect(host=credentials['POSTGRES_ADDRESS'],
                  database=credentials['POSTGRES_DBNAME'],
                  user=credentials['POSTGRES_USERNAME'],
                  password=credentials['POSTGRES_PASSWORD'],
                  port=credentials['POSTGRES_PORT'])

cur = conn.cursor()

# cur.execute("DROP TABLE SEA_WATER_QUALITY_TABLE;")

create_table_query = '''
      CREATE TABLE IF NOT EXISTS services_table
      (
        services_id SERIAL PRIMARY KEY,
        services TEXT
       ); 
       '''

cur.execute(create_table_query)
conn.commit()

cur.close()
conn.close()

# %% [markdown]
# # INSERT SEA_WATER_QUALITY_TABLE:

# %%
# %%time
# Wall time: 12min 51s
import psycopg2 as ps

# define credentials 
credentials = {'POSTGRES_ADDRESS' : 'test-surfers-bible-instance.cljoljhkgpfb.ap-southeast-2.rds.amazonaws.com', # change to your endpoint
               'POSTGRES_PORT' : 5432, # change to your port
               'POSTGRES_USERNAME' : 'ai_postgres', # change to your username
               'POSTGRES_PASSWORD' : 'postgres2309', # change to your password
               'POSTGRES_DBNAME' : 'test_surfers_bible_db'} # change to your db name

# create connection and cursor    
conn = ps.connect(host=credentials['POSTGRES_ADDRESS'],
                  database=credentials['POSTGRES_DBNAME'],
                  user=credentials['POSTGRES_USERNAME'],
                  password=credentials['POSTGRES_PASSWORD'],
                  port=credentials['POSTGRES_PORT'])

cur = conn.cursor()

fill_question_mark_str = str(tuple(["%s"  for i in services_df.columns.tolist()])).replace("'", "").replace(",", "")
fill_question_mark_str

for row in services_df.itertuples():
    data_tuple = tuple(row[1:])

    print("data_tuple = ", data_tuple)
    print(" ")
    
    cur.execute("""
                        INSERT INTO services_table
                        (
                            services
                         ) VALUES  
                         """ + fill_question_mark_str + " ;"
                , data_tuple)    

conn.commit()
cur.close()
conn.close()
# Out:
# data_tuple =  ('Coronary care unit',)
#
# data_tuple =  ('Intensive care unit',)
#
# data_tuple =  ('Oncology unit',)
#
# data_tuple =  ('Paediatric service',)
#
# data_tuple =  ('Psychiatric unit',)
#
# data_tuple =  ('Domiciliary care service',)
#
# data_tuple =  ('Geriatric assessment unit',)
#
# data_tuple =  ('Hospice care unit',)
#
# data_tuple =  ('Maintenance renal dialysis unit',)
#
# data_tuple =  ('Obstetric services',)
#
# data_tuple =  ('Rehabilitation unit',)
#
# data_tuple =  ('Alcohol and drug unit',)
#
# data_tuple =  ('Nursing home care unit',)
#
# data_tuple =  ('Diabetes unit',)
#
# data_tuple =  ('Epilepsy centre',)
#
# data_tuple =  ('Infectious diseases unit',)
#
# data_tuple =  ('Acute renal dialysis unit',)
#
# data_tuple =  ('Cardiac surgery unit',)
#
# data_tuple =  ('Bone marrow transplantation unit',)
#
# data_tuple =  ('Major plastic or reconstructive surgery unit',)
#
# data_tuple =  ('Clinical genetics unit',)
#
# data_tuple =  ('AIDS unit',)
#
# ...

# %%
hospital_services_df.State.unique()
# Out:
# array(['NSW', 'Vic', 'Qld', 'SA', 'WA', 'Tas', 'NT', 'ACT'], dtype=object)

# %%
hospital_services_df = hospital_services_df.loc[hospital_services_df["State"] == "Vic" , :]
hospital_services_df.shape
# Out:
# (704, 3)

# %% [markdown]
# # CREATE SEA_WATER_QUALITY_TABLE:

# %%
import psycopg2 as ps

# define credentials 
credentials = {'POSTGRES_ADDRESS' : 'test-surfers-bible-instance.cljoljhkgpfb.ap-southeast-2.rds.amazonaws.com', # change to your endpoint
               'POSTGRES_PORT' : 5432, # change to your port
               'POSTGRES_USERNAME' : 'ai_postgres', # change to your username
               'POSTGRES_PASSWORD' : 'postgres2309', # change to your password
               'POSTGRES_DBNAME' : 'test_surfers_bible_db'} # change to your db name

# create connection and cursor    
conn = ps.connect(host=credentials['POSTGRES_ADDRESS'],
                  database=credentials['POSTGRES_DBNAME'],
                  user=credentials['POSTGRES_USERNAME'],
                  password=credentials['POSTGRES_PASSWORD'],
                  port=credentials['POSTGRES_PORT'])

cur = conn.cursor()

# cur.execute("DROP TABLE SEA_WATER_QUALITY_TABLE;")

create_table_query = '''
      CREATE TABLE IF NOT EXISTS hospital_services_table
      (
        hospital_services_id SERIAL PRIMARY KEY,
        hospital_id INTEGER,
        services_id INTEGER,
        FOREIGN KEY (hospital_id) REFERENCES hospital_table(hospital_id) ON DELETE CASCADE,
        FOREIGN KEY (services_id) REFERENCES services_table(services_id) ON DELETE CASCADE
       ); 
       '''

cur.execute(create_table_query)
conn.commit()

cur.close()
conn.close()

# %% [markdown]
# # INSERT SEA_WATER_QUALITY_TABLE:

# %%
# %%time
# Wall time: 12min 51s
import psycopg2 as ps

# define credentials 
credentials = {'POSTGRES_ADDRESS' : 'test-surfers-bible-instance.cljoljhkgpfb.ap-southeast-2.rds.amazonaws.com', # change to your endpoint
               'POSTGRES_PORT' : 5432, # change to your port
               'POSTGRES_USERNAME' : 'ai_postgres', # change to your username
               'POSTGRES_PASSWORD' : 'postgres2309', # change to your password
               'POSTGRES_DBNAME' : 'test_surfers_bible_db'} # change to your db name

# create connection and cursor    
conn = ps.connect(host=credentials['POSTGRES_ADDRESS'],
                  database=credentials['POSTGRES_DBNAME'],
                  user=credentials['POSTGRES_USERNAME'],
                  password=credentials['POSTGRES_PASSWORD'],
                  port=credentials['POSTGRES_PORT'])

cur = conn.cursor()

fill_question_mark_str = str(tuple(["%s"  for i in hospital_services_df.columns.tolist()])).replace("'", "").replace(",", "")
fill_question_mark_str

for row in hospital_services_df[["Hospital", "Services"]].itertuples():
    data_tuple = tuple(row[1:])

    print("data_tuple = ", data_tuple)
    print(" ")
    
    cur.execute("""
                        INSERT INTO hospital_services_table
                        (
                            hospital_id,
                            services_id
                         ) VALUES  ((select hospital_id from hospital_table where  hospital_name = %s), 
                                    (select services_id from services_table where  services = %s)) 
                """
                , data_tuple)    

conn.commit()
cur.close()
conn.close()
# Out:
# data_tuple =  ('Albury Wodonga Health [Wodonga Campus]', 'Domiciliary care service')
#
# data_tuple =  ('Albury Wodonga Health [Wodonga Campus]', 'Geriatric assessment unit')
#
# data_tuple =  ('Albury Wodonga Health [Wodonga Campus]', 'Maintenance renal dialysis unit')
#
# data_tuple =  ('Albury Wodonga Health [Wodonga Campus]', 'Obstetric services')
#
# data_tuple =  ('Albury Wodonga Health [Wodonga Campus]', 'Rehabilitation unit')
#
# data_tuple =  ('Alpine Health [Bright]', 'Domiciliary care service')
#
# data_tuple =  ('Alpine Health [Bright]', 'Obstetric services')
#
# data_tuple =  ('Alpine Health [Mount Beauty]', 'Domiciliary care service')
#
# data_tuple =  ('Alpine Health [Mount Beauty]', 'Obstetric services')
#
# data_tuple =  ('Alpine Health [Myrtleford]', 'Domiciliary care service')
#
# data_tuple =  ('Alpine Health [Myrtleford]', 'Maintenance renal dialysis unit')
#
# data_tuple =  ('Alpine Health [Myrtleford]', 'Obstetric services')
#
# ...
